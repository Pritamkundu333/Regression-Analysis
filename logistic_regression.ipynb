# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  have_insurance
# 0   22               0
# 1   25               0
# 2   47               1
# 3   52               0
# 4   46               1

# %%
plt.scatter(df.age,df.have_insurance,marker = '+',color = 'red')
plt.xlim(0,100)
# Out:
# (0.0, 100.0)

# %%
x_train,x_test,y_train,y_test = train_test_split(df[['age']],df.have_insurance,train_size = 0.9)

# %%
x_test
# Out:
#     age
# 27   43
# 24   84
# 17   56

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([1, 1, 1], dtype=int64)

# %%
y_test == model.predict(x_test)
# Out:
# 27    False
# 24     True
# 17     True
# Name: have_insurance, dtype: bool

# %%
model.score(x_test,y_test)
# Out:
# 0.6666666666666666

# %%
model.predict_log_proba(x_test)
# Out:
# array([[-7.71183002e-01, -6.20762608e-01],
#        [-5.46798024e+00, -4.22867470e-03],
#        [-1.98320331e+00, -1.48068159e-01]])

# %%
df
# Out:
#     age  have_insurance
# 0    22               0
# 1    25               0
# 2    47               1
# 3    52               0
# 4    46               1
# 5    56               1
# 6    55               0
# 7    60               1
# 8    62               1
# 9    61               1
# 10   18               0
# 11   28               0
# 12   27               0
# 13   29               0
# 14   49               1
# 15   92               1
# 16   12               0
# 17   56               1
# 18   54               1
# 19   34               0
# 20   26               1
# 21   45               1
# 22   65               1
# 23   72               1
# 24   84               1
# 25   23               0
# 26   33               0
# 27   43               0
# 28   88               1
